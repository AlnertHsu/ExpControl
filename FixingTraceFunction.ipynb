# %%
import ExpControl
import numpy as np
import pandas as pd
import pickle
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.rcParams['lines.linewidth'] = 3.0
plt.rcParams['font.size'] = 22.0
plt.rcParams['xtick.labelsize'] = 22
plt.rcParams['ytick.labelsize'] = 22
plt.rcParams['axes.labelsize'] = 26
plt.style.use('seaborn-white')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9504\2537146792.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
meas = ExpControl.Measurements(instr=['vna'])
# Out:
# c:\Users\USER\Documents\GitHub\Qcodes\.conda\lib\site-packages\qcodes\instrument\instrument_base.py:143: QCoDeSDeprecationWarning: Parameter trace on instrument VNA does not correctly pass kwargs to its baseclass. A Parameter class must take `**kwargs` and forward them to its baseclass.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\USER\Documents\GitHub\Qcodes\.conda\lib\site-packages\qcodes\instrument\instrument_base.py:140, in InstrumentBase.add_parameter(self, name, parameter_class, **kwargs)
#     139 try:
# --> 140     param = parameter_class(name=name, instrument=self, **kwargs)
#     141 except TypeError:
#
# TypeError: __init__() got an unexpected keyword argument 'bind_to_instrument'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
meas.setup_vna(power=-30,avgs=1,measure='S11',format1='MLOG',format2='PHAS',format3='REAL',format4='PHAS')

# %%
tr = meas.trace(0e09,20.0e09,npts=1001)
# Out:
# Trace took 0:00:01.104063

# %%
plt.plot(tr[0],tr[1][0])
plt.show()

# %%
plt.plot(tr[0],tr[1][1])
plt.show()
